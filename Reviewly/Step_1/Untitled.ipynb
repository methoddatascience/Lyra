# %%
import pandas as pd
import numpy as np

# %%
#read file
data=pd.read_csv('yelp_review.csv')

# %%
data.shape
# Out:
# (5261668, 9)

# %%
data.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA
# 1  n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w
# 2  MV3CcKScW05u5LVfF6ok0g  bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g
# 3  IXvOzsEMYtiJI0CARmj77Q  bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA
# 4  L_9BTb55X0GDtThi6GlZ6w  bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q
#
#    stars        date                                               text  \
# 0      5  2016-05-28  Super simple place but amazing nonetheless. It...
# 1      5  2016-05-28  Small unassuming place that changes their menu...
# 2      5  2016-05-28  Lester's is located in a beautiful neighborhoo...
# 3      4  2016-05-28  Love coming here. Yes the place always needs t...
# 4      4  2016-05-28  Had their chocolate almond croissant and it wa...
#
#    useful  funny  cool
# 0       0      0     0
# 1       0      0     0
# ...

# %%
data['text'][9]
# Out:
# 'Love this place!\n\nPeggy is great with dogs and does a great job! She is very patience with him and will make any adjustments you need before you leave the store. My little guy has no problems coming here.\n\nThey also have very good bully sticks (the non-smelly ones) that my little guy and his friends love!'

# %%
data_business=pd.read_csv('yelp_business.csv')

# %%
data_business.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# ...

# %%
business=data_business[data_business['categories'].str.match('Restaurant')].copy()

# %%
business.head()
# Out:
#                business_id                          name neighborhood  \
# 14  fNMVV_ZX7CJSDWQGdOM8Nw  "Showmars Government Center"       Uptown
# 30  nbhBRhZtdaZmMMeb2i02pg             "Sunnyside Grill"          NaN
# 44  BnuzcebyB1AfxH0kjNWqSg    "Carrabba's Italian Grill"          NaN
# 55  c_XbaJqhm-5ycSBOkVUBmg                    "Don Taco"  Ville-Marie
# 57  spDZkD6cp0JUUm6ghIWHzA                   "Kitchen M"   Unionville
#
#                                       address       city state postal_code  \
# 14                             "600 E 4th St"  Charlotte    NC       28202
# 30                    "2777 Steeles Avenue W"    Toronto    ON     M3J 3K5
# 44                        "245 Lancaster Ave"     Frazer    PA       19355
# 55  "1855 Rue Saint Catherine Ouest, H3H 1M2"   Montreal    QC     H3H 1M2
# 57                        "8515 McCowan Road"    Markham    ON     L3P 5E5
#
#      latitude  longitude  stars  review_count  is_open  \
# ...

# %%
business.shape
# Out:
# (17844, 13)

# %%
f1=pd.merge(data, business, on='business_id')

# %%
f1.head(15)
# Out:
#                  review_id                 user_id             business_id  \
# 0   n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w
# 1   VrhTbFhgUa4zmx6jfqp_hQ  gKYaocnFD8Zi6rMt_mT-cw  VR6GpWIda3SfvPC-lg9H3w
# 2   XMJ_sHKVrtqJZ4IXA0I9wA  Vp_C7oIxeztbd2PchNBOHw  VR6GpWIda3SfvPC-lg9H3w
# 3   MhA0-xaUx4o4Pl_GQUr_ZQ  tB6vkXCS_8PIh-T9g8t6IQ  VR6GpWIda3SfvPC-lg9H3w
# 4   ziRcRyoy96J1Wj_WN-pM2Q  i1XAHltBpZC5zP5skcwVGw  VR6GpWIda3SfvPC-lg9H3w
# 5   LPVrO_myMgkype7u7PM5CA  sNtHrqKH0uHE9viVChJjuQ  VR6GpWIda3SfvPC-lg9H3w
# 6   Ar7q3t8ExtekFCEJQ9X-ZA  8_A_OdF_OS_PHHyDE2GiZw  VR6GpWIda3SfvPC-lg9H3w
# 7   7ImoVXWcOxOHRf8LAny_Og  ReDypdRmVA3wc-QG8HBKkQ  VR6GpWIda3SfvPC-lg9H3w
# 8   9BsOTU_a7M0RXU-UlAQffA  W_3WA6KUQSH8RDkB3bMDag  VR6GpWIda3SfvPC-lg9H3w
# 9   Mt4PIfKyF3sTiDEdphjrrA  zwDPx4s4nYyt-LURKsaUKA  VR6GpWIda3SfvPC-lg9H3w
# 10  IHu_eOiE5ZUeDNmPDNgWKw  kzXh1wIcCekofvPH5PGBgw  VR6GpWIda3SfvPC-lg9H3w
# ...

# %%
f1.shape
# Out:
# (897135, 21)

# %%
f1['text'][20]
# Out:
# "Franchement, cet endroit est exceptionnel, ce qui n'est pas peu dire compte tenu de l'offre en restauration à Montréal et du fait que la clientèle locale est de plus en plus exigeante et, disons-le, même un peu blasée. La qualité de tous les plats de notre tablée de quatre a été systématiquement irréprochable. L'atmosphère de l'endroit, qui accueille une quarantaine de personnes (incluant un bar de huit places, environ), est détendue et le personnel est charmant et attentif. Belle clientèle. Excellente soirée. Chaudement recommandé."

# %%
f1['text'][7]
# Out:
# "I had been hearing about the awesomeness of Tuck Shop for a quite a  while now so  when the opportunity came up to go check it out with a friend, it did not take much convincing to go.\n\nReservations are a must given the popularity of this little resto that could. Tuck Shop is quickly joining the ranks of Joe Beef, Liverpool House, Au Pieds de Cochon, and all the other popular eateries in Montreal. Thankfully I scored reservations at the last minute  for the same evening and was seriously looking forward to an awesome meal out with excellent company.\n\nReader, the food was impeccable. Not a bad note anywhere. I ordered the much recommended crispy pork belly and there's a reason why everyone is raving about it: it's THAT good. Melt-in-your-mouth perfection sitting in a smooth creamy sauce. It will definitely whet your appetite for more! The hanger steak was just as divine. A simple, juicy steak, which I ordered medium, and it came as medium, smothered with chimichurri sauce, that w
# ...

# %%
#number of character per comment
f1['text length'] = f1['text'].apply(len)
f1.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w
# 1  VrhTbFhgUa4zmx6jfqp_hQ  gKYaocnFD8Zi6rMt_mT-cw  VR6GpWIda3SfvPC-lg9H3w
# 2  XMJ_sHKVrtqJZ4IXA0I9wA  Vp_C7oIxeztbd2PchNBOHw  VR6GpWIda3SfvPC-lg9H3w
# 3  MhA0-xaUx4o4Pl_GQUr_ZQ  tB6vkXCS_8PIh-T9g8t6IQ  VR6GpWIda3SfvPC-lg9H3w
# 4  ziRcRyoy96J1Wj_WN-pM2Q  i1XAHltBpZC5zP5skcwVGw  VR6GpWIda3SfvPC-lg9H3w
#
#    stars_x        date                                               text  \
# 0        5  2016-05-28  Small unassuming place that changes their menu...
# 1        5  2015-01-31  Highly recommend checking this place out!  Tuc...
# 2        4  2011-10-23  This restaurant is part of the wave of trendy ...
# 3        5  2011-07-22  It's in a sketchy area, but it's upscale and l...
# 4        4  2014-11-01  A local friend introduced me to this jewel res...
#
# ...
